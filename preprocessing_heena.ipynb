# %%
import pandas as pd

# %%
a =[]
for i in range(12):
    file = pd.read_csv(f'jobkorea_data{i}.csv')
    a.append(file)

# %%
df = pd.concat(a, ignore_index=True)

# %%
df
# Out:
#            company       date work_type        job
# 0       오스템임플란트(주)  2022년 하반기        신입  경영·비즈니스기획  \
# 1       오스템임플란트(주)  2022년 하반기        신입  경영·비즈니스기획
# 2       오스템임플란트(주)  2022년 하반기        신입  경영·비즈니스기획
# 3       오스템임플란트(주)  2022년 하반기        신입  경영·비즈니스기획
# 4       오스템임플란트(주)  2022년 하반기        신입  경영·비즈니스기획
# ...            ...        ...       ...        ...
# 19630  (주)바로크레디트대부  2017년 상반기        신입         심사
# 19631    (주)KB손해사정  2015년 하반기        신입         심사
# 19632    (주)KB손해사정  2015년 하반기        신입         심사
# 19633    (주)KB손해사정  2015년 하반기        신입         심사
# 19634    (주)KB손해사정  2015년 하반기        신입         심사
#
#                                        question
# 0               오스템임플란트에 입사 지원한 동기/이유를 설명해 주세요.  \
# 1                   과거 경험 中 본인의 실패 사례를 소개해 주세요.
# 2                        본인의 열정 발휘 사례를 소개해 주세요.
# 3      입사 후 지원 분야에 본인이 기여할 수 있는 방안에 대해 설명해 주세요.
# 4           입사 지원 분야에 대한 본인의 직무 수행 경험을 설명해 주세요.
# ...                                         ...
# ...
